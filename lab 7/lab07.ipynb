# %%
import pandas as pd
import numpy as np

#import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from os import listdir
from os.path import isfile, join, dirname, abspath

# %%
# the length of records (if shorter, we need to add some zero rows)
NUMBER_TIMESTEPS = 100
# the number of features (from the data)
NUMBER_FEATURES = 202
# the number of classes/gestures
NUMBER_OUTPUTS = 2
# you can encode more than 1 but for this example we have binary output (circle/swipe)

# %%
# the directory where your data is
mypath = './data'

# creating a list with all the filenames
datafiles = [f for f in listdir('data') if isfile(join(mypath, f))]

# %%
# choose data we need
columns = ['handPalmPosition_X','handPalmPosition_Y','handPalmPosition_Z',
          'pitch', 'roll', 'yaw', 'GestureTypeCircle', 'GestureTypeSwipe',
          'wristPosition_X', 'wristPosition_Y','wristPosition_Z',
          'elbowPosition_X', 'elbowPosition_Y', 'elbowPosition_Z']

finger_names = ['Thumb', 'Index', 'Middle', 'Ring', 'Pinky']
bone_names = ['Metacarpal', 'Proximal', 'Intermediate', 'Distal']
    
for finger in finger_names:
    columns.append(finger + 'Length')
    columns.append(finger + 'Width')

for finger in finger_names:
    for bone in bone_names:
        columns.append(finger + bone + 'Start_X')
        columns.append(finger + bone + 'Start_Y')
        columns.append(finger + bone + 'Start_Z')
        columns.append(finger + bone + 'End_X')
        columns.append(finger + bone + 'End_Y')
        columns.append(finger + bone + 'End_Z')
        columns.append(finger + bone + 'Direction_X') 
        columns.append(finger + bone + 'Direction_Y') 
        columns.append(finger + bone + 'Direction_Z')

# %%
# Features
x = []
# Labels
y = []

for sample in datafiles:
    relative_path = 'data\\' + sample
    tmp = pd.read_csv(relative_path, usecols=columns)
    
    # Normalize the sample size: LSTM requires all inputs of the same size!
    print('{}\nsize raw = {}'.format(relative_path,tmp.shape))
    while tmp.shape[0] < NUMBER_TIMESTEPS:
        tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)

    if tmp.shape[0] > NUMBER_TIMESTEPS:
        tmp = tmp.head(100)
    print('size normalized = ',tmp.shape)
    
    tmp_x = tmp[[column for column in list(tmp.columns)
                 if column != 'GestureTypeCircle' 
                 and column != 'GestureTypeSwipe']]
    tmp_y = tmp[['GestureTypeCircle', 'GestureTypeSwipe']]
        
    x.append(tmp_x)
    y.append(tmp_y)
# Out:
# data\circle1.csv
# size raw = (37, 204)
# size normalized =  (100, 204)
# data\circle10.csv
# size raw = (60, 204)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# ...
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# size normalized =  (100, 204)
# data\swipe6.csv
# size raw = (99, 204)
# size normalized =  (100, 204)
# data\swipe7.csv
# size raw = (92, 204)
# size normalized =  (100, 204)
# data\swipe8.csv
# size raw = (51, 204)
# size normalized =  (100, 204)
# data\swipe9.csv
# size raw = (99, 204)
# size normalized =  (100, 204)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)
# C:\Users\getab\AppData\Local\Temp\ipykernel_49036\1026764117.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp = tmp.append(pd.Series(0, index=tmp.columns), ignore_index=True)

# %%
# Each sample requires labels of [1,NUMBER_OUTPUTS] size (not a list)
y_new = list()
for cur_label in y:
    tmp = np.array(cur_label.loc[0])
    y_new.append(tmp)
y = np.array(y_new)
#print(y)

# %%
# Set a percentage of test set fraction
test_size = 0.30 # 30%

# Divide data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_size, shuffle=True)
len_train = len(X_train)
len_test = len(X_test)

print ('Number of train samples = {}\nNumber of test samples = {}'.format(len_train, len_test))
print ('There is ',type(X_train),' of ',type(X_train[0]))

# Turn list(DataFrame) into numpy.ndarray with [len_train, NUMBER_TIMESTEPS, NUMBER_FEATURES]
X_train = np.array(X_train)
X_test = np.array(X_test)
print('The list was turned into <numpy.ndarray>')
# Out:
# Number of train samples = 14
# Number of test samples = 6
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>

# %%
def build_model(numOfNodes=256,dropout_probability=0.5):
    model = models.Sequential()    
    # an input layer that expects:
    # 1 or more samples, NUMBER_TIMESTEPS time steps and NUMBER_FEATURES features.
    
    # 1st LSTM layer
    model.add(layers.LSTM(numOfNodes, return_sequences=True, input_shape=(NUMBER_TIMESTEPS, NUMBER_FEATURES)) )
    
    # 2nd LSTM layer
    model.add(layers.LSTM(numOfNodes, input_shape=(NUMBER_TIMESTEPS, NUMBER_FEATURES)) )
    
    # Hidden fully connected layers of the neural network
    model.add(layers.Dense(512,activation='relu'))  
    model.add(layers.Dropout(dropout_probability))
    model.add(layers.Dense(256,activation='relu'))    
    model.add(layers.Dropout(dropout_probability))
    model.add(layers.Dense(512,activation='relu'))
    
    # Classification layer of the neural network
    model.add(layers.Dense(NUMBER_OUTPUTS, activation='softmax'))
    
    opt = Adam(learning_rate=0.002)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    # this shows the network structure 
    model.summary()
    
    return model

# %%
def CreateCustomModel(testing=0.3, numOfNodes=256, dropout_probability=0.5):

# Divide data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=testing, shuffle=True)
    len_train = len(X_train)
    len_test = len(X_test)

    print ('Number of train samples = {}\nNumber of test samples = {}'.format(len_train, len_test))
    print ('There is ',type(X_train),' of ',type(X_train[0]))

    # Turn list(DataFrame) into numpy.ndarray with [len_train, NUMBER_TIMESTEPS, NUMBER_FEATURES]
    X_train = np.array(X_train)
    X_test = np.array(X_test)
    print('The list was turned into <numpy.ndarray>')
    
    # creating the model
    model = build_model(numOfNodes,dropout_probability)
    
    # training the model
    model.fit(X_train, y_train, epochs=10, batch_size=len_train)
    
    # testing the model
    test_loss, test_acc = model.evaluate(X_test, y_test, batch_size=len_train)
    y_pred = model.predict(X_test)
    matches = (y_pred == y_test)
    print('Total of matches: %d' % (matches.sum()))

    match_rate = matches.sum() / float(len(matches))
    print('Match rate: %.2f' % (match_rate))

# %% [markdown]
# ## Exercise 1:

# %%
CreateCustomModel(testing=0.4)
# Out:
# Number of train samples = 12
# Number of test samples = 8
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 100, 256)          470016
#
#  lstm_17 (LSTM)              (None, 256)               525312
#
#  dense_32 (Dense)            (None, 512)               131584
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  dense_33 (Dense)            (None, 256)               131328
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 512)               131584
#
#  dense_35 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 1,390,850
# Trainable params: 1,390,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 9s 9s/step - loss: 0.6760 - accuracy: 0.6667
# Epoch 2/10
# 1/1 [==============================] - 1s 612ms/step - loss: 0.6910 - accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6124 - accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 1s 685ms/step - loss: 0.5848 - accuracy: 0.5833
# Epoch 5/10
# 1/1 [==============================] - 1s 968ms/step - loss: 0.4521 - accuracy: 0.8333
# Epoch 6/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.3278 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 1s 804ms/step - loss: 0.1196 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 4s 4s/step - loss: 3.9231e-05 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 6s 6s/step - loss: 1.6978e-04 - accuracy: 1.0000
# 1/1 [==============================] - 6s 6s/step - loss: 4.8277 - accuracy: 0.7500
# 1/1 [==============================] - 3s 3s/step
# Total of matches: 0
# Match rate: 0.00

# %%
CreateCustomModel(testing=0.2)
# Out:
# Number of train samples = 16
# Number of test samples = 4
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 100, 256)          470016
#
#  lstm_19 (LSTM)              (None, 256)               525312
#
#  dense_36 (Dense)            (None, 512)               131584
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_37 (Dense)            (None, 256)               131328
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_38 (Dense)            (None, 512)               131584
#
#  dense_39 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 1,390,850
# Trainable params: 1,390,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 10s 10s/step - loss: 0.7068 - accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6355 - accuracy: 0.5625
# Epoch 3/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.5442 - accuracy: 0.5625
# Epoch 4/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.5238 - accuracy: 0.5625
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.3174 - accuracy: 0.8125
# Epoch 6/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.2159 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.4417 - accuracy: 0.9375
# Epoch 9/10
# 1/1 [==============================] - 2s 2s/step - loss: 6.8466e-04 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 2s 2s/step - loss: 2.8557 - accuracy: 0.8750
# 1/1 [==============================] - 3s 3s/step - loss: 13.5873 - accuracy: 0.2500
# 1/1 [==============================] - 2s 2s/step
# Total of matches: 1
# Match rate: 0.25

# %% [markdown]
# ## Exercise 2:

# %%
CreateCustomModel(numOfNodes=256)
# Out:
# Number of train samples = 14
# Number of test samples = 6
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 100, 256)          470016
#
#  lstm_21 (LSTM)              (None, 256)               525312
#
#  dense_40 (Dense)            (None, 512)               131584
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_41 (Dense)            (None, 256)               131328
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_42 (Dense)            (None, 512)               131584
#
#  dense_43 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 1,390,850
# Trainable params: 1,390,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 7s 7s/step - loss: 0.7083 - accuracy: 0.4286
# Epoch 2/10
# 1/1 [==============================] - 0s 331ms/step - loss: 0.6555 - accuracy: 0.5714
# Epoch 3/10
# 1/1 [==============================] - 0s 339ms/step - loss: 0.6427 - accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 293ms/step - loss: 0.5624 - accuracy: 0.7143
# Epoch 5/10
# 1/1 [==============================] - 0s 294ms/step - loss: 0.4909 - accuracy: 0.7143
# Epoch 6/10
# 1/1 [==============================] - 0s 294ms/step - loss: 0.3738 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 0s 360ms/step - loss: 0.1733 - accuracy: 0.9286
# Epoch 8/10
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 301ms/step - loss: 2.3866e-05 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 482ms/step - loss: 2.8610e-06 - accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step - loss: 7.1253 - accuracy: 0.6667
# 1/1 [==============================] - 2s 2s/step
# Total of matches: 4
# Match rate: 0.67

# %%
CreateCustomModel(numOfNodes=128)
# Out:
# Number of train samples = 14
# Number of test samples = 6
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 100, 128)          169472
#
#  lstm_23 (LSTM)              (None, 128)               131584
#
#  dense_44 (Dense)            (None, 512)               66048
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  dense_45 (Dense)            (None, 256)               131328
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  dense_46 (Dense)            (None, 512)               131584
#
#  dense_47 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 631,042
# Trainable params: 631,042
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 8s 8s/step - loss: 0.7206 - accuracy: 0.4286
# Epoch 2/10
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6809 - accuracy: 0.6429
# Epoch 3/10
# 1/1 [==============================] - 0s 218ms/step - loss: 0.6606 - accuracy: 0.5714
# Epoch 4/10
# 1/1 [==============================] - 0s 213ms/step - loss: 0.5867 - accuracy: 0.7143
# Epoch 5/10
# 1/1 [==============================] - 0s 222ms/step - loss: 0.4666 - accuracy: 0.9286
# Epoch 6/10
# 1/1 [==============================] - 0s 287ms/step - loss: 0.3055 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 0s 278ms/step - loss: 0.1222 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 212ms/step - loss: 2.6416e-04 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 223ms/step - loss: 3.7466e-07 - accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step
# Total of matches: 6
# Match rate: 1.00

# %% [markdown]
# ## Exercise 3:

# %%
CreateCustomModel(dropout_probability=0.4)
# Out:
# Number of train samples = 14
# Number of test samples = 6
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 100, 256)          470016
#
#  lstm_25 (LSTM)              (None, 256)               525312
#
#  dense_48 (Dense)            (None, 512)               131584
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_49 (Dense)            (None, 256)               131328
#
#  dropout_25 (Dropout)        (None, 256)               0
#
#  dense_50 (Dense)            (None, 512)               131584
#
#  dense_51 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 1,390,850
# Trainable params: 1,390,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 9s 9s/step - loss: 0.6583 - accuracy: 0.7143
# Epoch 2/10
# 1/1 [==============================] - 0s 358ms/step - loss: 0.6561 - accuracy: 0.6429
# Epoch 3/10
# 1/1 [==============================] - 0s 419ms/step - loss: 0.4997 - accuracy: 0.6429
# Epoch 4/10
# 1/1 [==============================] - 1s 503ms/step - loss: 0.3525 - accuracy: 0.6429
# Epoch 5/10
# 1/1 [==============================] - 0s 289ms/step - loss: 0.3544 - accuracy: 0.9286
# Epoch 6/10
# 1/1 [==============================] - 0s 304ms/step - loss: 0.1253 - accuracy: 0.9286
# Epoch 7/10
# 1/1 [==============================] - 0s 324ms/step - loss: 0.1954 - accuracy: 0.9286
# Epoch 8/10
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0710 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0053 - accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0081 - accuracy: 1.0000
# 1/1 [==============================] - 2s 2s/step
# Total of matches: 0
# Match rate: 0.00

# %%
CreateCustomModel(dropout_probability=0.6)
# Out:
# Number of train samples = 14
# Number of test samples = 6
# There is  <class 'list'>  of  <class 'pandas.core.frame.DataFrame'>
# The list was turned into <numpy.ndarray>
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 100, 256)          470016
#
#  lstm_27 (LSTM)              (None, 256)               525312
#
#  dense_52 (Dense)            (None, 512)               131584
#
#  dropout_26 (Dropout)        (None, 512)               0
#
#  dense_53 (Dense)            (None, 256)               131328
#
#  dropout_27 (Dropout)        (None, 256)               0
#
#  dense_54 (Dense)            (None, 512)               131584
#
#  dense_55 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 1,390,850
# Trainable params: 1,390,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 6s 6s/step - loss: 0.7122 - accuracy: 0.5714
# Epoch 2/10
# 1/1 [==============================] - 0s 287ms/step - loss: 0.6650 - accuracy: 0.6429
# Epoch 3/10
# 1/1 [==============================] - 0s 326ms/step - loss: 0.6216 - accuracy: 0.5714
# Epoch 4/10
# 1/1 [==============================] - 0s 315ms/step - loss: 0.5754 - accuracy: 0.5714
# Epoch 5/10
# 1/1 [==============================] - 0s 311ms/step - loss: 0.5118 - accuracy: 0.6429
# Epoch 6/10
# 1/1 [==============================] - 0s 305ms/step - loss: 0.4432 - accuracy: 0.7143
# Epoch 7/10
# 1/1 [==============================] - 0s 313ms/step - loss: 0.1999 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 286ms/step - loss: 3.3468e-04 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 305ms/step - loss: 0.5076 - accuracy: 0.9286
# 1/1 [==============================] - 2s 2s/step - loss: 4.5398 - accuracy: 0.6667
# 1/1 [==============================] - 2s 2s/step
# Total of matches: 2
# Match rate: 0.33
